# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from ta.trend import ADXIndicator

from get_stock_data import get_stock_information
from get_stock_data import get_stock_historical_data
from get_stock_data import draw_plotly_stock_chart
from get_stock_data import draw_simple_stock_chart
from get_stock_data import draw_plotly_stock_chart

from news_scraper import get_us_stock_news

from financeAnalysisTools import process_stock_data

# %%
daily = get_stock_historical_data('005930',
                                          from_date='01/06/2021',
                                          interval='Daily')

daily = process_stock_data(daily)

adx = ADXIndicator(daily['High'], daily['Low'], daily['Close'], 13, False)

# %%
adx.adx().plot()
# Out:
# c:\users\nanal\anaconda3\envs\stock_research\lib\site-packages\ta\trend.py:768: RuntimeWarning: invalid value encountered in double_scalars
#   dip[i] = 100 * (self._dip[i] / self._trs[i])
# c:\users\nanal\anaconda3\envs\stock_research\lib\site-packages\ta\trend.py:772: RuntimeWarning: invalid value encountered in double_scalars
#   din[i] = 100 * (self._din[i] / self._trs[i])
# <AxesSubplot:xlabel='Date'>
